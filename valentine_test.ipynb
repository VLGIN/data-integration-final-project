# %%
import pandas as pd
import valentine

# %%
cellphones = pd.read_csv("cellphones.csv")

# %%
list_name = list(cellphones)

# %%
cellphones = cellphones[list_name[1:]]

# %%
shopee = pd.read_csv("shopee_sample.csv")

# %%
tiki = pd.read_csv("tiki_sample.csv")

# %%
shopee.loc[0]['item_basic']
# Out:
# "{'itemid': 6241244465, 'shopid': 48782032, 'name': '[ RẺ VÔ ĐỊCH ] Điện thoại Xiaomi Redmi 4X - RAM: 3 GB Bộ nhớ trong: 32 GB . Chơi PUBG-Free Fire mượt / FULLBOX', 'label_ids': [1000279, 1000710, 1000270, 1001711, 1001791, 1001857, 1000752, 1000753, 1001959, 1002105, 1002120, 1002182, 1002229, 1002263, 1002296, 1002343, 1002408, 1002409, 1002410, 1002433, 1002587, 1002597, 1002763, 1002792, 1002847, 1002899, 1003133, 1003169, 1002498, 1003258, 1003259, 1003283, 1003928, 1004067, 1004068, 1004078, 1004168, 1004169, 1004212, 1004213, 1004265, 1004293, 1004344, 1004420, 1004423, 1004879, 1004921, 1004927, 1005026, 1005061, 1006117, 1006199, 1006306, 1006642, 1006669, 1006805, 1007328, 1007695, 1007627, 1007773, 1008093, 1008529, 1008755, 1008875, 1009058, 1009202, 1009396, 1009525, 1009931, 1010210, 1010310, 1010452, 1010666, 1010881, 1011293, 1011470, 1011685, 1011843, 1011909, 1012192, 1012514, 1012822, 1012981, 1013158, 1013400, 1013503, 1013624, 1013801, 1015067, 1015746, 1015802]
# ...

# %%
list(shopee)
# Out:
# ['item_basic',
#  'adsid',
#  'campaignid',
#  'distance',
#  'match_type',
#  'ads_keyword',
#  'deduction_info',
#  'collection_id',
#  'display_name',
#  'campaign_stock',
#  'json_data',
#  'tracking_info',
#  'itemid',
#  'shopid',
#  'algo_image',
#  'fe_flags',
#  'item_type',
#  'foody_item',
#  'search_item_tracking',
#  'bff_item_tracking',
#  'personalized_labels',
#  'biz_json']

# %%
tiki
# Out:
#           id            sku  \
# 0  166145145  8765818936965
# 1  163798660  7519033658804
# 2  179489992  4131909459219
# 3  179455426  7427976063775
# 4  163798558  3798081629609
# 5   52002453  3532343992386
# 6  159887168  8495142315118
# 7  117347869  9493948405298
# 8   29446449  1678381397812
# 9  129356132  7186903080245
#
#                                                 name  \
# 0  Tổng đài điện thoại Adsun FX208PC hàng chính hãng
# 1  Máy tính bảng Lenovo Tab M10 - Gen 2 - Hàng ch...
# 2  Điện thoại Samsung Galaxy Z Flip3 5G (8GB/256G...
# 3  Điện thoại Samsung Galaxy Z Fold3 5G (12GB/512...
# 4  Máy tính bảng Xiaomi Pad 5 256GB - Hàng chính ...
# 5     Cisco Unified IP Phone 7962G - Hàng chính hãng
# 6  Điện Thoại Samsung Galaxy S21 FE 5G RAM 8GB - ...
# 7  ĐIỆN THOẠI HỘI NGHỊ YEALINK CP960 -HÀNG CHÍNH ...
# 8                     Điện thoại không dây IP 622CW
# 9  Điện thoại bàn IP Yealink SIP-T30 - Hàng chính...
#
# ...

# %%
cellphones
# Out:
#                                            name             price  \
# 0             iPhone 11 64GB I Chính hãng VN/A       11.490.000 ₫
# 1     iPhone 13 Pro Max 128GB | Chính hãng VN/A      29.590.000 ₫
# 2             iPhone 11 Pro Max Chính hãng VN/A      26.000.000 ₫
# 3    iPhone 12 Pro Max 128GB I Chính hãng VN/A       27.000.000 ₫
# 4         Nubia Red Magic 7 Obsidian 12GB 128GB      18.990.000 ₫
# ..                                          ...               ...
# 479                                  Realme Q3s  Đăng ký nhận tin
# 480                                  Realme C21  Đăng ký nhận tin
# 481                             Oppo Reno 8 Pro  Đăng ký nhận tin
# 482                              Huawei Mate 40  Đăng ký nhận tin
# 483                     Xiaomi Mi Mix 4 Pro Max  Đăng ký nhận tin
#
#                                                  image
# 0    https://cdn.cellphones.com.vn/media/catalog/pr...
# 1    https://cdn.cellphones.com.vn/media/catalog/pr...
# ...

# %%
matcher = valentine.algorithms.DistributionBased()

# %%
matches = valentine.valentine_match(tiki, tiki, matcher)
# Out:
# /Users/leo/Projects/data-integration-final-project/venv/lib/python3.8/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)

# %%
matches
# Out:
# {(('table_1', 'id'), ('table_2', 'id')): 1.0,
#  (('table_1', 'sku'), ('table_2', 'sku')): 1.0,
#  (('table_1', 'name'), ('table_2', 'name')): 1.0,
#  (('table_1', 'url_key'), ('table_2', 'url_key')): 1.0,
#  (('table_1', 'url_path'), ('table_2', 'url_path')): 1.0,
#  (('table_1', 'type'), ('table_2', 'type')): 1.0,
#  (('table_1', 'brand_name'), ('table_2', 'brand_name')): 1.0,
#  (('table_1', 'short_description'), ('table_2', 'short_description')): 1.0,
#  (('table_1', 'price'), ('table_2', 'price')): 1.0,
#  (('table_1', 'list_price'), ('table_2', 'list_price')): 1.0,
#  (('table_1', 'list_price'), ('table_2', 'original_price')): 1.0,
#  (('table_1', 'original_price'), ('table_2', 'list_price')): 1.0,
#  (('table_1', 'original_price'), ('table_2', 'original_price')): 1.0,
#  (('table_1', 'badges'), ('table_2', 'badges')): 1.0,
#  (('table_1', 'badges_new'), ('table_2', 'badges_new')): 1.0,
#  (('table_1', 'discount'), ('table_2', 'discount')): 1.0,
# ...

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/leo/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/leo/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /Users/leo/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True
