# %%
import pandas as pd

# %%
from airflow.dags.operator.utils import *

# %%
clean_data()

# %%
shopee = pd.read_csv("data-source/shopee/shopee_sample.csv")
tiki = pd.read_csv("data-source/tiki/tiki_sample.csv")
sendo = pd.read_csv("data-source/sendo/sendo_sample.csv")
media = pd.read_csv("mediamart.csv")

# %%
import valentine

# %%
matcher = valentine.algorithms.Cupid()

# %%
matches = valentine.valentine_match(shopee, tiki, matcher)

# %%
shopee.isna().sum()
# Out:
# Unnamed: 0                  0
# itemid                      0
# shopid                      0
# name                        0
# label_ids                   0
#                            ..
# is_live_streaming_price    10
# is_mart                     0
# pack_size                  10
# deep_discount_skin          9
# is_service_by_shopee        0
# Length: 77, dtype: int64

# %%
shopee
# Out:
#    Unnamed: 0      itemid     shopid  \
# 0           0  6241244465   48782032
# 1           1  7643658564   48810739
# 2           2  7645349256   11171175
# 3           3  5676072135  108110554
# 4           4  8470192900   98999745
# 5           5  6949478858  208445880
# 6           6  4049790569   11171175
# 7           7  8540278060  134747469
# 8           8  4646285575   11171175
# 9           9  6852365551  108110554
#
#                                                 name  \
# 0  [ RẺ VÔ ĐỊCH ] Điện thoại Xiaomi Redmi 4X - RA...
# 1  SAMSUNG GALAXY J7 PRO (J730) 2sim Ram 3G/32G m...
# 2  điện thoại Oppo Neo 9 (Oppo A37) 2sim ram 2G b...
# 3  điện thoại Xiaomi Redmi Note 5 Pro 2sim (4GB/6...
# 4                     Điện Thoại Nokia Bàn Phím 1280
# 5  Điện thoại độc nắp gập samsung s3600i cho ngườ...
# 6  điện thoại Xiaomi Redmi 4A 2sim ram 2G/16G mới...
# 7  Điện thoại Xiaomi Mi 11 Pro Ram 8GB - Hàng Nhậ...
# 8  điện thoại Samsung Galaxy J5 2016 2sim Chính H...
# ...
