# %%
from pymongo import MongoClient

# %%
import pandas as pd

# %%
client = MongoClient("mongodb+srv://longgiang:longgiang2010@cluster0.npw0zsg.mongodb.net/")

db = client["data-integration"]

# %%
def get_data(collec_name):
    collec = db[collec_name]
    data = collec.find()
    df = pd.DataFrame(list(data))
    df.drop(["_id", "index"], axis=1, inplace=True)
    return df

# %%
collec = db["didongthongminh"]

# %%
data = collec.find()

# %%
data

# %%
didongthongminh = get_data("didongthongminh")

# %%
import pandas as pd
import re

from utils import process_name, process_text


def generic_format(df):
    df.rename(columns={item: re.sub("\n", "", str(item)).strip().lower() for item in list(df)}, inplace=True)
    list_column = list(df)
    for col in list_column:
        df[col] = df[col].apply(process_text)
    return df


# def preprocess(df):
#     df['name'] = df['name'].apply(process_name())
#     df.reset_index(inplace=True)
#
#     for index, row in df.iterrows():
#         if row["Mã sản phẩm"] is None:
#             row["Mã sản phẩm"] = row["name"]
#         elif row["name"] is None:
#             row["name"] = row["Mã sản phẩm"]
#     return df


def preprocess_thegioididong(df):
    df["Name"] = df["Name"].apply(process_name)
    df.rename(columns={item: str(item).strip().lower() for item in list(df)}, inplace=True)
    return generic_format(df)


def preprocess_mediamart(df):
    df["name"] = df["name"].apply(process_name)
    df.rename(columns={item: str(item).strip().lower() for item in list(df)}, inplace=True)
    return generic_format(df)


def preprocess_didongthongminh(df):
    num_col = len(list(df))
    df["name"] = df["name"].apply(process_name)
    df.rename(columns={item: str(item).strip().lower() for item in list(df)}, inplace=True)
    df = df.dropna(axis=1, thresh=num_col)
    return generic_format(df)


def preprocess_cellphones(df):
    pass


def preprocess_phongvu(df):
    pass


# def preprocess_tiki(df):
#     df = df.dropna(thresh=15)
#     df.reset_index(drop=True, inplace=True)
#     df.rename(columns={"Model": "name", "ROM": "Bộ nhớ"}, inplace=True)
#     print(list(df))
#     df["name"] = df["name"].apply(process_name)
#     df.rename(columns={item: str(item).strip().lower() for item in list(df)}, inplace=True)
#     return generic_format(df)

# %%
preprocess_didongthongminh(didongthongminh)
# Out:
# /tmp/ipykernel_92948/1584161622.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={item: re.sub("\n", "", str(item)).strip().lower() for item in list(df)}, inplace=True)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
# /tmp/ipykernel_92948/1584161622.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(process_text)
#            price                                               name  \
# 0     4.190.000đ                     redmi note 9 pin khủng 6000mah
# 1     3.890.000đ                                redmi 10 chính hãng
# 2     2.990.000đ                      mi 8 youth edition ram cũ hộp
# 3     2.990.000đ  a7 chính hãng thiết kế thời thượng,năng lượng ...
# 4     4.990.000đ                             poco m4 pro chính hãng
# ..           ...                                                ...
# 350  26.990.000đ                      iphone 13 mini chính hãng vna
# 351  22.990.000đ        iphone 12 pro max like pin 100% đẹp như mới
# 352   7.990.000đ                                 r7 plus chính hãng
# 353   9.390.000đ            iphone xs max cũ nguyên bản đẹp như mới
# 354   1.999.999đ                                 find 7a chính hãng
#
#               băng tần - sim  \
# 0             2g, 3g, 4g lte
# 1                        nan
# 2    gsm / cdma / hspa / lte
# 3               gsm/hspa/lte
# 4                        nan
# ..                       ...
# 350                      nan
# 351                      nan
# 352               2g/3g, lte
# 353               2g/3g, lte
# 354               2g/3g, lte
#
#                                               màn hình  \
# 0    1080 x 2340 pixels, 395 ppi, 6.53 inches, ips lcd
# 1                                                  nan
# 2              6.26 inches, ips lcd 1080 x 2280 pixels
# 3    6.2 inches, 95.9 cm2 (~81.6% screen-to-body ra...
# 4                                                  nan
# ..                                                 ...
# 350                                                nan
# 351                                                nan
# 352                             ips lcd, 6.0", full hd
# 353                               6.5" super retina hd
# 354                             ips lcd, 5.5", full hd
#
#                                         cpu  \
# 0                    snapdragon 662 (11 nm)
# 1                                       nan
# 2            qualcomm sdm660 snapdragon 660
# 3    qualcomm sdm450 snapdragon 450 (14 nm)
# 4                                       nan
# ..                                      ...
# 350                                     nan
# 351                                     nan
# 352                 qualcomm snapdragon 615
# 353                        apple a12 bionic
# 354                 qualcomm snapdragon 801
#
#                                                    ram  \
# 0    0      0       6gb1       nan2      6 gb3     ...
# 1    0      0       6gb1       nan2      6 gb3     ...
# 2    0      0       6gb1       nan2      6 gb3     ...
# 3    0      0       6gb1       nan2      6 gb3     ...
# 4    0      0       6gb1       nan2      6 gb3     ...
# ..                                                 ...
# 350  0      0       6gb1       nan2      6 gb3     ...
# 351  0      0       6gb1       nan2      6 gb3     ...
# 352  0      0       6gb1       nan2      6 gb3     ...
# 353  0      0       6gb1       nan2      6 gb3     ...
# 354  0      0       6gb1       nan2      6 gb3     ...
#
#                                           bộ nhớ trong  \
# 0    0      0       128gb1         nan2      128 gb...
# 1    0      0       128gb1         nan2      128 gb...
# 2    0      0       128gb1         nan2      128 gb...
# 3    0      0       128gb1         nan2      128 gb...
# 4    0      0       128gb1         nan2      128 gb...
# ..                                                 ...
# 350  0      0       128gb1         nan2      128 gb...
# 351  0      0       128gb1         nan2      128 gb...
# 352  0      0       128gb1         nan2      128 gb...
# 353  0      0       128gb1         nan2      128 gb...
# 354  0      0       128gb1         nan2      128 gb...
#
#                                               cảm biến  \
# 0                                     cảm biến vân tay
# 1                                                  nan
# 2                                                  nan
# 3    cảm biến ánh sáng, cảm biến gia tốc kế, cảm bi...
# 4                                                  nan
# ..                                                 ...
# 350                                                nan
# 351                                                nan
# 352     fingerprint, accelerometer, proximity, compass
# 353  face id, barometer, three‑axis gyro, accelerom...
# 354                  accelerometer, proximity, compass
#
#                             camera sau  camera trước  ... hỗ trợ sạc tối đa  \
# 0    chính 48mp+8mp+2mp, hdr, panorama           8mp  ...               nan
# 1                                  nan           nan  ...              18 w
# 2                    dual 12 mp + 5 mp  24 mp, 0.9µm  ...               nan
# 3                     dual 13mp + 2 mp  16 mp, f/2.0  ...               nan
# 4                                  nan           nan  ...               nan
# ..                                 ...           ...  ...               ...
# 350                                nan           nan  ...              20 w
# 351                                nan           nan  ...              20 w
# 352                              13 mp        8.0 mp  ...               nan
# 353                         dual 12 mp        7.0 mp  ...               nan
# 354                              13 mp        5.0 mp  ...               nan
#
#                                          công nghệ pin  \
# 0                                                  nan
# 1                                        sạc pin nhanh
# 2                                                  nan
# 3                                                  nan
# 4                                        sạc nhanh 33w
# ..                                                 ...
# 350  tiết kiệm pinsạc pin nhanhsạc không dây magsaf...
# 351  sạc pin nhanh sạc không dây magsafe tiết kiệm ...
# 352                                                nan
# 353                                                nan
# 354                                                nan
#
#                                bảo mật nâng cao          xem phim  \
# 0                                           nan               nan
# 1    mở khoá khuôn mặtmở khoá vân tay cạnh viền            avimp4
# 2                                           nan               nan
# 3                                           nan               nan
# 4                               mở khoá vân tay               nan
# ..                                          ...               ...
# 350                   mở khoá khuôn mặt face id  h.264(mpeg4-avc)
# 351                   mở khoá khuôn mặt face id  h.264(mpeg4-avc)
# 352                                         nan               nan
# 353                                         nan               nan
# 354                                         nan               nan
#
#                  nghe nhạc                              kích thước khối lượng  \
# 0                      nan                                                nan
# 1           oggmp3midiflac  dài 161 mm - ngang 75.53 mm - dày 8.92 mm - nặ...
# 2                      nan                                                nan
# 3                      nan                                                nan
# 4                      nan  dài 163.6 mm - ngang 75.8 mm - dày 8.8 mm - nặ...
# ..                     ...                                                ...
# 350             mp3flacaac  dài 131.5 mm - ngang 64.2 mm - dày 7.65 mm - n...
# 351  flac mp3 aac lossless  dài 160.8 mm - ngang 78.1 mm - dày 7.4 mm - nặ...
# 352                    nan                                                nan
# 353                    nan                                                nan
# 354                    nan                                                nan
#
#        đèn flash thời điểm ra mắt                                ghi âm  \
# 0            nan              nan                                   nan
# 1            nan              nan                                   nan
# 2            nan              nan                                   nan
# 3            nan              nan                                   nan
# 4             có           3/2022                                   nan
# ..           ...              ...                                   ...
# 350           có          09/2021  có (microphone chuyên dụng chống ồn)
# 351  đèn led kép              nan  có (microphone chuyên dụng chống ồn)
# 352          nan              nan                                   nan
# 353          nan              nan                                   nan
# 354          nan              nan                                   nan
#
#            date
# 0    2022-07-05
# 1    2022-07-05
# 2    2022-07-05
# 3    2022-07-05
# 4    2022-07-05
# ..          ...
# 350  2022-07-05
# 351  2022-07-05
# 352  2022-07-05
# 353  2022-07-05
# 354  2022-07-05
#
# [355 rows x 45 columns]
